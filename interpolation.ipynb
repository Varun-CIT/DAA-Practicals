# %%
import time
import random
import sys
def interpolation_search(arr,target):
    low,high=0,len(arr)-1
    comparisons=0
    while low<=high and target>=arr[low] and target<=arr[high]:
        comparisons+=1
        if low==high:
            if arr[low]==target:
                return low,comparisons
            return -1,comparisons
        pos=low+((high-low)*(target-arr[low])//(arr[high]-arr[low]))
        if pos<low or pos>high:
            return -1,comparisons
        if arr[pos]==target:
            return pos,comparisons
        if arr[pos]<target:
            low=pos+1
        else:
            high=pos-1
    return -1,comparisons
def binary_search(arr,target):
    low,high=0,len(arr)-1
    comparisons=0
    while low<=high:
        comparisons+=1
        mid=(low+high)//2
        if arr[mid]==target:
            return mid,comparisons
        if arr[mid]<target:
            low=mid+1
        else:
            high=mid-1
    return -1,comparisons
def performance_analysis():
    sizes=[1000,5000,10000,50000,100000,500000,1000000]
    print(f"{'Size':>10} {'Interpolation':>15} {'Binary':>10}")
    for size in sizes:
        arr=sorted(random.sample(range(size*10),size))
        target=random.choice(arr)
        start=time.time()
        _,comp_interp=interpolation_search(arr,target)
        end=time.time()
        interp_time=end-start
        start=time.time()
        _,comp_binary=binary_search(arr,target)
        end=time.time()
        binary_time=end-start
        print(f"{size:>10} {interp_time:.6f} sec ({comp_interp} comps) {binary_time:.6f} sec ({comp_binary} comps)")
arr = [2, 5, 10, 15, 23, 35, 48, 60, 75, 90, 105, 120]
target = 35
idx,comparisons = interpolation_search(arr, target)
idx, comps = interpolation_search(arr, target)
print(f"Array: {arr}")
print(f"Searching for: {target}")
print(f"Found at index: {idx}, Comparisons: {comps}")
print()
performance_analysis()
# Out:
# Array: [2, 5, 10, 15, 23, 35, 48, 60, 75, 90, 105, 120]
# Searching for: 35
# Found at index: 5, Comparisons: 3
#
#       Size   Interpolation     Binary
#       1000 0.000004 sec (3 comps) 0.000004 sec (10 comps)
#       5000 0.000009 sec (3 comps) 0.000010 sec (12 comps)
#      10000 0.000012 sec (5 comps) 0.000006 sec (13 comps)
#      50000 0.000016 sec (4 comps) 0.000009 sec (15 comps)
#     100000 0.000011 sec (5 comps) 0.000006 sec (14 comps)
#     500000 0.000010 sec (2 comps) 0.000007 sec (19 comps)
#    1000000 0.000011 sec (4 comps) 0.000009 sec (20 comps)
